# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Load log file from "models/{MODEL_ID}/train_log.csv"

# %%
df = pd.read_pickle('../../models/20200727_2255/trainlog.csv')

# %%
plt.plot(df.Epoch, df.loss)
plt.plot(df.Epoch, df.val_loss)
plt.xlim(0,300)
# Out:
# (0.0, 300.0)

# %%
plt.plot(df.Epoch, df.hm2_loss)
plt.plot(df.Epoch, df.val_hm2_loss)
plt.xlim(0,300)
plt.ylim(0,5e-4)
# Out:
# (0.0, 0.0005)

# %%
plt.plot(df.Epoch, df.push_loss)
plt.plot(df.Epoch, df.val_push_loss)
plt.xlim(0,400)
# Out:
# (0.0, 400.0)

# %%
plt.plot(df.Epoch, df.pull_loss)
plt.plot(df.Epoch, df.val_pull_loss)
plt.xlim(0,400)
plt.ylim(0,2e-4)
# Out:
# (0.0, 0.0002)
